# %%
Name="mahi"
print(Name)
# Out:
# mahi

# %%
a=10
b=20
sum=a+b
print(sum)
# Out:
# 30

# %%
a=10
b=20
c=30
product=a*b*c
print(product)
# Out:
# 6000

# %%
a=10
b=20
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# a= 20
# b= 10

# %%
x=20
y=30
z=50
average=(x*y*z)/30
print("average",average)
# Out:
# average 1000.0
