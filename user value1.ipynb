# %%
name=int(input())
age=int(input())
print("name and age",name , age)
# Out:
#  6
#  5
# name and age 6 5

# %%
name=int(input())
age=int(input())
print("name and age",name , age)

# %%
a=int(input())
b=int(input())
c=int(input())
d=a+b+c
print(d)
# Out:
#  6
#  6
#  6
# 18

# %%
a=10 
b=20 
print (a+b)
# Out:
# 30
