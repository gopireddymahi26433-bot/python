# %%
if (True):
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
college = input()
if college == "like":
  print("They like to go college")
else:
  print("Don't like to go college")
# Out:
#  like
# They like to go college

# %%
rcb = "win" 
if rcb == "win":
   print("yes")
else:
   print("no")
# Out:
# yes

# %%
meghna = input()

if meghna == "died":
    print("Surya meets Priya")
else:
    print("Surya weds Meghna")
# Out:
#  alive
# Surya weds Meghna

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:  26
# Even

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print(a, "is greater")
else:
    print(b, "is greater")
# Out:
# Enter first number:  2
# Enter second number:  6
# 6 is greater

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Enter age:  26
# Eligible to vote

# %%
age = int(input("Enter age: "))

if age >= 60:
    print("Senior Citizen")
else:
    print("Not a Senior Citizen")
# Out:
# Enter age:  56
# Not a Senior Citizen

# %%
num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("Divisible by both")
else:
    print("Not divisible by both")
# Out:
# Enter a number:  36
# Not divisible by both

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks:  68
# Grade C

# %%
num = int(input("Enter a number: "))

if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Enter a number:  36
# Not divisible by 5

# %%
ch = input("Enter a character: ")

if ch.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character:  r
# Consonant

# %%
year = int(input("Enter year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year:  2007
# Not a Leap Year

# %%
a = int(input("First number: "))
b = int(input("Second number: "))
c = int(input("Third number: "))

if a > b and a > c:
    print(a, "is largest")
elif b > c:
    print(b, "is largest")
else:
    print(c, "is largest")
# Out:
# First number:  5
# Second number:  6
# Third number:  8
# 8 is largest
